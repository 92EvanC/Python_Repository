# %%
import pandas as pd
import numpy as np
import os
path= r'/Users/evancarr/Desktop/CF Exercises/Instacart Basket Analysis'

# %%
ords_prods_merge=pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'ETC_ords_prods_merge.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998     138            28                   6                 11
# 1   1977647     138            30                   6                 17
# 2    389851     709             2                   0                 21
# 3    652770     764             1                   3                 13
# 4   1813452     764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order reordered _merge
# ...

# %%
ords_prods_merge.shape
# Out:
# (32433030, 14)

# %% [markdown]
# ### Creating subset of data

# %%
df=ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
#defining function
def price_label(row):
    if row['prices'] <=5:
        return 'Low-range product'
    elif (row['prices']>5) and (row['prices']<=15):
        return 'Mid-range product'
    elif row['prices'] >15:
        return 'High range'
    else: return 'Not enough data'

# %%
df['price_range']=df.apply(price_label, axis=1)
# Out:
# /var/folders/z7/kqs18yh15zq9sxssld03yyvh0000gn/T/ipykernel_14016/2703828020.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range']=df.apply(price_label, axis=1)

# %%
df.shape
# Out:
# (1000000, 15)

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998     138            28                   6                 11
# 1   1977647     138            30                   6                 17
# 2    389851     709             2                   0                 21
# 3    652770     764             1                   3                 13
# 4   1813452     764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order reordered _merge  \
# ...

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# price_range
# Mid-range product    659418
# Low-range product    331238
# High range             9344
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 24.5

# %% [markdown]
# ## Setting price range flag

# %%
df.loc[df['prices']>15, 'price_range_loc']= 'High-range product'
# Out:
# /var/folders/z7/kqs18yh15zq9sxssld03yyvh0000gn/T/ipykernel_14016/1883637897.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices']>15, 'price_range_loc']= 'High-range product'

# %%
df.loc[(df['prices']<=15) & (df['prices']>5), 'price_range_loc']= 'Mid-range product'

# %%
df.loc[df['prices']<=5, 'price_range_loc']= 'Low-range product'

# %% [markdown]
# # Question 1
#
# ## Creating and setting price_range flag on ords_prods_merge

# %%
ords_prods_merge.loc[ords_prods_merge['prices']>15, 'price_range_loc']= 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices']<=15) & (ords_prods_merge['prices']>5), 'price_range_loc']= 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices']<=5, 'price_range_loc']= 'Low-range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21889009
# Low-range product     10126339
# High-range product      417682
# Name: count, dtype: int64

# %% [markdown]
# ## Findnign the busiest day of the week

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna=False)
# Out:
# orders_day_of_week
# 0    6209410
# 1    5665604
# 6    4500101
# 2    4217610
# 5    4209334
# 3    3843929
# 4    3787042
# Name: count, dtype: int64

# %% [markdown]
# ## Question 1 continued
# ### Creating busiest day of the week column

# %%
result = []
for value in ords_prods_merge["orders_day_of_week"]:
    if value ==0:
        result.append("Busiest day")
    elif value ==4:
        result.append("Least busy")
    else:
        result.append("Regularly busy")

# %%
#naming colun busiest_day
ords_prods_merge['busiest_day']=result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    22436578
# Busiest day        6209410
# Least busy         3787042
# Name: count, dtype: int64

# %% [markdown]
# # Question 2
# ## Amending busiest_day column into plural 'busiest_days' & creating new column for slowest days

# %%
result = []
for value in ords_prods_merge["orders_day_of_week"]:
    if value ==0:
        result.append("Busiest days")
    elif value ==1:
        result.append("Busiest days")
    elif value ==3:
        result.append("Slowest days")
    elif value ==4:
        result.append("Slowest days")
    else:
        result.append("Regularly busy")

# %%
#Creating busiest day column
ords_prods_merge['volume_days']=result

# %%
#checking volume of days column
ords_prods_merge['volume_days'].value_counts(dropna = False)
# Out:
# volume_days
# Regularly busy    12927045
# Busiest days      11875014
# Slowest days       7630971
# Name: count, dtype: int64

# %% [markdown]
# ### Dropping 'busiest_day' column because it is redundant

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998     138            28                   6                 11
# 1   1977647     138            30                   6                 17
# 2    389851     709             2                   0                 21
# 3    652770     764             1                   3                 13
# 4   1813452     764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order reordered _merge  \
# ...

# %%
#dropping busiest_days column because it is unnecessary
ords_prods_merge=ords_prods_merge.drop(columns=['busiest_day'])

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998     138            28                   6                 11
# 1   1977647     138            30                   6                 17
# 2    389851     709             2                   0                 21
# 3    652770     764             1                   3                 13
# 4   1813452     764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order reordered _merge  \
# ...

# %% [markdown]
# # Question 4
# ## Creating 'busiest_period_of_day' column

# %%
ords_prods_merge.value_counts(['order_hour_of_day'], dropna=False)
# Out:
# order_hour_of_day
# 10                   2764288
# 11                   2738483
# 14                   2691448
# 15                   2664420
# 13                   2663169
# 12                   2620719
# 16                   2537358
# 9                    2456591
# 17                   2089385
# 8                    1719888
# 18                   1637858
# 19                   1259335
# 20                    976991
# 7                     891900
# 21                    796341
# 22                    634715
# 23                    402593
# 6                     290763
# 0                     218925
# 1                     115780
# 5                      88054
# 2                      69429
# 4                      53280
# 3                      51317
# Name: count, dtype: int64

# %% [markdown]
# ## Creating function that orders hours of day as 'most','average', & 'fewest'

# %%
result_2 = []
for value in ords_prods_merge['order_hour_of_day']:
    if value in [0,1,2,3,4,5,6,23]:
        result_2.append('Fewest orders')
    elif value in [9,10,11,12,13,14,15,16]:
        result_2.append ('Average orders')
    else:
        result_2.append ('Most orders')

# %%
result_2
# Out:
# ['Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Fewest orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
# ...

# %%
#creating column 'Busiest_period_of_day'
ords_prods_merge['busiest_period_of_day']=result_2

# %% [markdown]
# # Question 5
# ## Printing frequency

# %%
ords_prods_merge['Busiest_period_of_day'].value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Busiest_period_of_day'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ...

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998     138            28                   6                 11
# 1   1977647     138            30                   6                 17
# 2    389851     709             2                   0                 21
# 3    652770     764             1                   3                 13
# 4   1813452     764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order reordered _merge  \
# ...

# %% [markdown]
# # Exporting file to Prepared Data folder

# %%
#exporting dataframe to.pkl
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ETC_4.7.pkl'))
