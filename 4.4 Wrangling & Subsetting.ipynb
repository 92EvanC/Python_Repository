# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Import Orders Data

# %%
#import orders data
df_ord = pd.read_csv(r'/Users/evancarr/Desktop/CF Exercises/Instacart Basket Analysis/02 Data/Original Data/orders.csv', index_col = False)

# %% [markdown]
# Import Products Data

# %%
df_ord.shape
# Out:
# (3421083, 6)

# %%
#import Products
df_prod=pd.read_csv(r'/Users/evancarr/Desktop/CF Exercises/Instacart Basket Analysis/02 Data/Original Data/products.csv', index_col = False)

# %%
df_prod.shape
# Out:
# (49693, 5)

# %% [markdown]
# Create path name

# %%
#create pathname
#Pathname
path=r'/Users/evancarr/Desktop/CF Exercises/Instacart Basket Analysis'

# %% [markdown]
# Import Departments Data

# %%
#import departments.csv
df_dep = pd.read_csv(os.path.join(path,'02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
df_dep.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_dep.shape
#
# NameError: name 'df_dep' is not defined

# %% [markdown]
# Drop Eval Set Column

# %%
#dropping eval set from columns
df_ord.drop(columns=['eval_set'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 2
#       1 #dropping eval set from columns
# ----> 2 df_ord.drop(columns=['eval_set'])
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
# ...

# %% [markdown]
# Rename dow to day of the week

# %%
#rename day of the week
df_ord.rename(columns={'order_dow': 'orders_day_of_week'}, inplace= True)

df_ord.head()
# Out:
#   order_id customer_number  order_number  orders_day_of_week  \
# 0  2539329               1             1                   2
# 1  2398795               1             2                   3
# 2   473747               1             3                   3
# 3  2254736               1             4                   4
# 4   431534               1             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %% [markdown]
# Change order id data type

# %%
#changing order id data type
df_ord['order_id'] = df_ord['order_id'].astype('str')

# %%
df_ord['order_id']
# Out:
# 0          2539329
# 1          2398795
# 2           473747
# 3          2254736
# 4           431534
#             ...
# 3421078    2266710
# 3421079    1854736
# 3421080     626363
# 3421081    2977660
# 3421082     272231
# Name: order_id, Length: 3421083, dtype: object

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %% [markdown]
# Transpose department.csv

# %%
#transposing department.csv
df_dep_t=df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# Reset the department index

# %%
#resetting index on department.csv
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %% [markdown]
# Create new header

# %%
#creating new header
new_header=df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %% [markdown]
# Delet un-needed rows

# %%
#deleting first row of dept.csv
df_dep_t_new=df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
#clean department index created
df_dep_t_new.columns= new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# Create department data dictionary

# %%
#data dictionary created
data_dict= df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_ord
# Out:
#         order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0        2539329        1    prior             1                   2
# 1        2398795        1    prior             2                   3
# 2         473747        1    prior             3                   3
# 3        2254736        1    prior             4                   4
# 4         431534        1    prior             5                   4
# ...          ...      ...      ...           ...                 ...
# 3421078  2266710   206209    prior            10                   5
# 3421079  1854736   206209    prior            11                   4
# 3421080   626363   206209    prior            12                   1
# 3421081  2977660   206209    prior            13                   1
# 3421082   272231   206209    train            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# ...

# %% [markdown]
# Drop eval column from orders

# %%
#dropping eval column from orders.csv
df_ord=df_ord.drop(columns=['eval_set'])

# %%
df_ord
# Out:
#         order_id  user_id  order_number  orders_day_of_week  \
# 0        2539329        1             1                   2
# 1        2398795        1             2                   3
# 2         473747        1             3                   3
# 3        2254736        1             4                   4
# 4         431534        1             5                   4
# ...          ...      ...           ...                 ...
# 3421078  2266710   206209            10                   5
# 3421079  1854736   206209            11                   4
# 3421080   626363   206209            12                   1
# 3421081  2977660   206209            13                   1
# 3421082   272231   206209            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
df_ord.head(20)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
# 10  1187899        1            11                   4                  8
# 11  2168274        2             1                   2                 11
# ...

# %% [markdown]
# 02. I changed user id type to string

# %%
#changing user id type
df_ord['user_id'] = df_ord['user_id'].astype('str')

# %% [markdown]
# 03. I renamed the user id column to 'customer number'

# %%
#renaming user column to customer number
df_ord.rename(columns={'user_id':'customer_number'}, inplace= True)

# %%
df_ord.head(20)
# Out:
#    order_id customer_number  order_number  orders_day_of_week  \
# 0   2539329               1             1                   2
# 1   2398795               1             2                   3
# 2    473747               1             3                   3
# 3   2254736               1             4                   4
# 4    431534               1             5                   4
# 5   3367565               1             6                   2
# 6    550135               1             7                   1
# 7   3108588               1             8                   1
# 8   2295261               1             9                   1
# 9   2550362               1            10                   4
# 10  1187899               1            11                   4
# 11  2168274               2             1                   2
# 12  1501582               2             2                   5
# 13  1901567               2             3                   1
# ...

# %%
df_ord.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count  3.421083e+06        3.421083e+06       3.421083e+06
# mean   1.715486e+01        2.776219e+00       1.345202e+01
# std    1.773316e+01        2.046829e+00       4.226088e+00
# min    1.000000e+00        0.000000e+00       0.000000e+00
# 25%    5.000000e+00        1.000000e+00       1.000000e+01
# 50%    1.100000e+01        3.000000e+00       1.300000e+01
# 75%    2.300000e+01        5.000000e+00       1.600000e+01
# max    1.000000e+02        6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %%
df_ord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 6 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                object
#  1   customer_number         object
#  2   order_number            int64
#  3   orders_day_of_week      int64
#  4   order_hour_of_day       int64
#  5   days_since_prior_order  float64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 156.6+ MB

# %%
df_ord.count()
# Out:
# order_id                  3421083
# customer_number           3421083
# order_number              3421083
# orders_day_of_week        3421083
# order_hour_of_day         3421083
# days_since_prior_order    3214874
# dtype: int64

# %% [markdown]
# 04. Busiest hour for placing orders is 10am

# %%
#busiest time customer place orders
df_ord['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: count, dtype: int64

# %% [markdown]
# 05. Produce department = the number 4 in data dictionary

# %%
#finding department number '4'
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# 06. Creating Breakfast subset

# %%
#creating breakfast subset
df_breakfast= df_prod[df_prod['department_id']==14]

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %% [markdown]
# 07. Dinner party products subset

# %%
#creating dinner party subset
df_dinner_party=df_prod.loc[df_prod['department_id'].isin([5,20,7,12])]

# %%
df_dinner_party
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %% [markdown]
# 08. Product id shows there are 7650 rows

# %%
#count of dinner party products
df_dinner_party.count()
# Out:
# product_id       7650
# product_name     7647
# aisle_id         7650
# department_id    7650
# prices           7650
# dtype: int64

# %% [markdown]
# 09. Finding all data on user number 1

# %%
#finding all data on 'customer 1'
df_user_1 = df_ord[df_ord['customer_number']=='1']

# %%
df_user_1
# Out:
#    order_id customer_number  order_number  orders_day_of_week  \
# 0   2539329               1             1                   2
# 1   2398795               1             2                   3
# 2    473747               1             3                   3
# 3   2254736               1             4                   4
# 4    431534               1             5                   4
# 5   3367565               1             6                   2
# 6    550135               1             7                   1
# 7   3108588               1             8                   1
# 8   2295261               1             9                   1
# 9   2550362               1            10                   4
# 10  1187899               1            11                   4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# 2                  12                    21.0
# ...

# %% [markdown]
# 10. Describing basic details about customer 1

# %%
df_user_1.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count     11.000000           11.000000          11.000000
# mean       6.000000            2.636364          10.090909
# std        3.316625            1.286291           3.477198
# min        1.000000            1.000000           7.000000
# 25%        3.500000            1.500000           7.500000
# 50%        6.000000            3.000000           8.000000
# 75%        8.500000            4.000000          13.000000
# max       11.000000            4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
df_user_1.head()
# Out:
#   order_id customer_number  order_number  orders_day_of_week  \
# 0  2539329               1             1                   2
# 1  2398795               1             2                   3
# 2   473747               1             3                   3
# 3  2254736               1             4                   4
# 4   431534               1             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_user_1.tail()
# Out:
#    order_id customer_number  order_number  orders_day_of_week  \
# 6    550135               1             7                   1
# 7   3108588               1             8                   1
# 8   2295261               1             9                   1
# 9   2550362               1            10                   4
# 10  1187899               1            11                   4
#
#     order_hour_of_day  days_since_prior_order
# 6                   9                    20.0
# 7                  14                    14.0
# 8                  16                     0.0
# 9                   8                    30.0
# 10                  8                    14.0

# %% [markdown]
# Exporting Dataframes

# %%
#exporting orders to prepared data folder as 'orders_wrangled.csv'
df_ord.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv'))

# %%
#exporting departments to prepared data as 'department_wrangled.csv'
df_dep_t_new.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'departments_wrangled.csv'))
